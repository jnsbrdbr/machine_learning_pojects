# %% [markdown]
# <a href="https://colab.research.google.com/github/jnsbrdbr/machine_learning_pojects/blob/master/fmnist_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import expand_dims, zeros, ones, asarray
from numpy.random import randn, randint

from keras.datasets.fashion_mnist import load_data
from keras.optimizers import Adam
from keras.models import Model, Sequential

from keras.layers import Input, Dense, Reshape, Flatten, Conv2D, Conv2DTranspose
from keras.layers import LeakyReLU, Dropout, Lambda, Activation

#from keras.utils import to_categorical

from matplotlib import pyplot as plt
from keras import backend as K
import numpy as np

# %%
def get_images_ready(n_classes=10):
    (trainX, trainy), (_, _) = load_data()
    X = np.expand_dims(trainX, axis=-1)
    X = X.astype('float32')
    X = X/255.  # scale from [0,255] to [0,1]  
    print(X.shape, trainy.shape)
    return [X, trainy]

#Pick a subset of images. 
num_images = 120
def select_subset_images(dataset, n_samples=num_images, n_classes=10):
 	X, y = dataset
 	X_list, y_list = list(), list()
 	n_per_class = int(n_samples / n_classes) #Number of samples per class. 
 	for i in range(n_classes):
         X_with_class = X[y == i] # get all images for this class
         ix = randint(0, len(X_with_class), n_per_class) # choose random images for each class
         [X_list.append(X_with_class[j]) for j in ix] # add to list
         [y_list.append(i) for j in ix]
 	return np.asarray(X_list), np.asarray(y_list) #Returns a list of 2 numpy arrays corresponding to X and Y

#Define the dataset.
dataset = get_images_ready() 
#Get subset images and corresponding labels
X, Y = select_subset_images(dataset)



from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

#### NOTE: We will be using sparse_categorical_crossentropy loss so we will not convert Y to categorical ####

#Define Model with BatchNormalization and Dropout
# define cnn model

model = Sequential()
model.add(Conv2D(32, (3, 3), strides=(2,2), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3,3), strides=(2,2), padding='same', activation='relu'))
model.add(Conv2D(128, (3,3), strides=(2,2), padding='same', activation='relu'))

model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))
	# compile model
#opt = SGD(lr=0.01, momentum=0.9)
opt = Adam(lr=0.0002, beta_1=0.5)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define model
print(model.summary())

history = model.fit(X_train, y_train, 
                    epochs=100, batch_size=64, 
                    validation_data=(X_test, y_test), 
                    verbose=1)

model.save('cnn_model_for_mnist_100epochs.h5')

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


#Test the model on all test data - 10,000 images

from keras.models import load_model
# load the model
my_model = load_model('cnn_model_for_mnist_100epochs.h5')

# load the dataset
(_, _), (test_X, test_y) = load_data()

# expand to 3d, e.g. add channels
test_X = np.expand_dims(test_X, axis=-1)

# convert from ints to floats
test_X = test_X.astype('float32')

# scale from [0,255] to [-1,1]
test_X = test_X /255.

# evaluate the model
_, test_acc = my_model.evaluate(test_X, test_y, verbose=0)
print('Test Accuracy: %.3f%%' % (test_acc * 100))


# Predicting the Test set results
y_pred_test = model.predict(test_X)
prediction_test = np.argmax(y_pred_test, axis=1)

# Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(test_y, prediction_test)
sns.heatmap(cm, annot=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28, 1) (60000,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 13, 13, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 10)                20490
#
# =================================================================
# Total params: 113,162
# Trainable params: 113,162
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# None
# Epoch 1/100
# 2/2 [==============================] - 1s 285ms/step - loss: 2.2991 - accuracy: 0.0729 - val_loss: 2.2851 - val_accuracy: 0.0833
# Epoch 2/100
# 2/2 [==============================] - 0s 55ms/step - loss: 2.2672 - accuracy: 0.1250 - val_loss: 2.2779 - val_accuracy: 0.1667
# Epoch 3/100
# 2/2 [==============================] - 0s 61ms/step - loss: 2.2137 - accuracy: 0.2917 - val_loss: 2.2686 - val_accuracy: 0.1667
# Epoch 4/100
# 2/2 [==============================] - 0s 73ms/step - loss: 2.1836 - accuracy: 0.3229 - val_loss: 2.2576 - val_accuracy: 0.1667
# Epoch 5/100
# 2/2 [==============================] - 0s 68ms/step - loss: 2.1666 - accuracy: 0.3229 - val_loss: 2.2460 - val_accuracy: 0.1667
# Epoch 6/100
# 2/2 [==============================] - 0s 74ms/step - loss: 2.1174 - accuracy: 0.3958 - val_loss: 2.2327 - val_accuracy: 0.2083
# Epoch 7/100
# 2/2 [==============================] - 0s 64ms/step - loss: 2.0693 - accuracy: 0.3750 - val_loss: 2.2187 - val_accuracy: 0.2083
# Epoch 8/100
# 2/2 [==============================] - 0s 57ms/step - loss: 2.0269 - accuracy: 0.3958 - val_loss: 2.1997 - val_accuracy: 0.2500
# Epoch 9/100
# 2/2 [==============================] - 0s 69ms/step - loss: 1.9850 - accuracy: 0.4167 - val_loss: 2.1750 - val_accuracy: 0.3333
# Epoch 10/100
# 2/2 [==============================] - 0s 193ms/step - loss: 1.9508 - accuracy: 0.4583 - val_loss: 2.1425 - val_accuracy: 0.3333
# Epoch 11/100
# 2/2 [==============================] - 0s 95ms/step - loss: 1.8773 - accuracy: 0.5000 - val_loss: 2.1089 - val_accuracy: 0.3750
# Epoch 12/100
# 2/2 [==============================] - 0s 129ms/step - loss: 1.8478 - accuracy: 0.5625 - val_loss: 2.0708 - val_accuracy: 0.3750
# Epoch 13/100
# 2/2 [==============================] - 0s 114ms/step - loss: 1.7709 - accuracy: 0.5833 - val_loss: 2.0390 - val_accuracy: 0.4167
# Epoch 14/100
# 2/2 [==============================] - 0s 115ms/step - loss: 1.7508 - accuracy: 0.5312 - val_loss: 1.9954 - val_accuracy: 0.4167
# Epoch 15/100
# 2/2 [==============================] - 0s 115ms/step - loss: 1.6764 - accuracy: 0.5521 - val_loss: 1.9369 - val_accuracy: 0.4167
# Epoch 16/100
# 2/2 [==============================] - 0s 129ms/step - loss: 1.6119 - accuracy: 0.5729 - val_loss: 1.8740 - val_accuracy: 0.4583
# Epoch 17/100
# 2/2 [==============================] - 0s 97ms/step - loss: 1.4942 - accuracy: 0.6875 - val_loss: 1.8058 - val_accuracy: 0.4583
# Epoch 18/100
# 2/2 [==============================] - 0s 148ms/step - loss: 1.4573 - accuracy: 0.6771 - val_loss: 1.7443 - val_accuracy: 0.4583
# Epoch 19/100
# 2/2 [==============================] - 0s 161ms/step - loss: 1.3679 - accuracy: 0.6875 - val_loss: 1.7121 - val_accuracy: 0.4583
# Epoch 20/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.2677 - accuracy: 0.6875 - val_loss: 1.6662 - val_accuracy: 0.4583
# Epoch 21/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.2605 - accuracy: 0.7083 - val_loss: 1.5888 - val_accuracy: 0.4583
# Epoch 22/100
# 2/2 [==============================] - 0s 102ms/step - loss: 1.1507 - accuracy: 0.7083 - val_loss: 1.5107 - val_accuracy: 0.5000
# Epoch 23/100
# 2/2 [==============================] - 0s 131ms/step - loss: 1.1200 - accuracy: 0.7083 - val_loss: 1.4184 - val_accuracy: 0.5833
# Epoch 24/100
# 2/2 [==============================] - 0s 105ms/step - loss: 1.1006 - accuracy: 0.7083 - val_loss: 1.3578 - val_accuracy: 0.5417
# Epoch 25/100
# 2/2 [==============================] - 0s 218ms/step - loss: 1.0560 - accuracy: 0.6875 - val_loss: 1.3213 - val_accuracy: 0.5417
# Epoch 26/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.9733 - accuracy: 0.7396 - val_loss: 1.2970 - val_accuracy: 0.5833
# Epoch 27/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.9357 - accuracy: 0.7396 - val_loss: 1.2521 - val_accuracy: 0.5417
# Epoch 28/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.8938 - accuracy: 0.7917 - val_loss: 1.1887 - val_accuracy: 0.6667
# Epoch 29/100
# 2/2 [==============================] - 0s 96ms/step - loss: 0.8284 - accuracy: 0.8125 - val_loss: 1.1598 - val_accuracy: 0.6250
# Epoch 30/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.8470 - accuracy: 0.7500 - val_loss: 1.1471 - val_accuracy: 0.6250
# Epoch 31/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.7667 - accuracy: 0.7604 - val_loss: 1.0932 - val_accuracy: 0.6250
# Epoch 32/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.7612 - accuracy: 0.8021 - val_loss: 1.0715 - val_accuracy: 0.7083
# Epoch 33/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.7683 - accuracy: 0.7396 - val_loss: 1.0294 - val_accuracy: 0.6667
# Epoch 34/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.6891 - accuracy: 0.8229 - val_loss: 1.0180 - val_accuracy: 0.6667
# Epoch 35/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.6880 - accuracy: 0.7708 - val_loss: 1.0436 - val_accuracy: 0.7500
# Epoch 36/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.6537 - accuracy: 0.8333 - val_loss: 1.0391 - val_accuracy: 0.7083
# Epoch 37/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7099 - accuracy: 0.7500 - val_loss: 1.0471 - val_accuracy: 0.6667
# Epoch 38/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.6118 - accuracy: 0.8021 - val_loss: 1.0381 - val_accuracy: 0.7083
# Epoch 39/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.6727 - accuracy: 0.7917 - val_loss: 0.9951 - val_accuracy: 0.7500
# Epoch 40/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.6241 - accuracy: 0.8542 - val_loss: 0.9624 - val_accuracy: 0.7083
# Epoch 41/100
# 2/2 [==============================] - 0s 93ms/step - loss: 0.5957 - accuracy: 0.7917 - val_loss: 0.9775 - val_accuracy: 0.6667
# Epoch 42/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.6468 - accuracy: 0.7812 - val_loss: 0.9939 - val_accuracy: 0.6667
# Epoch 43/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5833 - accuracy: 0.8229 - val_loss: 1.0067 - val_accuracy: 0.6667
# Epoch 44/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5483 - accuracy: 0.8438 - val_loss: 0.9716 - val_accuracy: 0.7083
# Epoch 45/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5370 - accuracy: 0.8542 - val_loss: 0.9679 - val_accuracy: 0.6667
# Epoch 46/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.4976 - accuracy: 0.8542 - val_loss: 0.9475 - val_accuracy: 0.7083
# Epoch 47/100
# 2/2 [==============================] - 0s 183ms/step - loss: 0.4908 - accuracy: 0.8646 - val_loss: 0.9348 - val_accuracy: 0.7083
# Epoch 48/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.5513 - accuracy: 0.8021 - val_loss: 0.9547 - val_accuracy: 0.6667
# Epoch 49/100
# 2/2 [==============================] - 0s 149ms/step - loss: 0.4991 - accuracy: 0.8333 - val_loss: 0.9551 - val_accuracy: 0.6667
# Epoch 50/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4393 - accuracy: 0.8438 - val_loss: 0.9133 - val_accuracy: 0.7083
# Epoch 51/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.4863 - accuracy: 0.8438 - val_loss: 0.8938 - val_accuracy: 0.7917
# Epoch 52/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.4112 - accuracy: 0.9167 - val_loss: 0.9033 - val_accuracy: 0.6667
# Epoch 53/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.4667 - accuracy: 0.8958 - val_loss: 0.9230 - val_accuracy: 0.7083
# Epoch 54/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.3883 - accuracy: 0.9062 - val_loss: 0.9198 - val_accuracy: 0.6667
# Epoch 55/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.4083 - accuracy: 0.8854 - val_loss: 0.9319 - val_accuracy: 0.6667
# Epoch 56/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.3654 - accuracy: 0.9062 - val_loss: 0.9416 - val_accuracy: 0.7083
# Epoch 57/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.3912 - accuracy: 0.9167 - val_loss: 0.9383 - val_accuracy: 0.7083
# Epoch 58/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.3885 - accuracy: 0.8854 - val_loss: 0.8950 - val_accuracy: 0.6667
# Epoch 59/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.3858 - accuracy: 0.8854 - val_loss: 0.8427 - val_accuracy: 0.7500
# Epoch 60/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.3786 - accuracy: 0.8958 - val_loss: 0.8449 - val_accuracy: 0.7500
# Epoch 61/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.3668 - accuracy: 0.8958 - val_loss: 0.9013 - val_accuracy: 0.7083
# Epoch 62/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3988 - accuracy: 0.8854 - val_loss: 0.9094 - val_accuracy: 0.6667
# Epoch 63/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.3062 - accuracy: 0.8958 - val_loss: 0.8818 - val_accuracy: 0.7083
# Epoch 64/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.3433 - accuracy: 0.9167 - val_loss: 0.9021 - val_accuracy: 0.7083
# Epoch 65/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3517 - accuracy: 0.8958 - val_loss: 0.9019 - val_accuracy: 0.7500
# Epoch 66/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3499 - accuracy: 0.9062 - val_loss: 0.9152 - val_accuracy: 0.7083
# Epoch 67/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3383 - accuracy: 0.8958 - val_loss: 0.9217 - val_accuracy: 0.6667
# Epoch 68/100
# 2/2 [==============================] - 0s 178ms/step - loss: 0.3142 - accuracy: 0.8958 - val_loss: 0.8941 - val_accuracy: 0.6667
# Epoch 69/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.3356 - accuracy: 0.9062 - val_loss: 0.8807 - val_accuracy: 0.7083
# Epoch 70/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.3251 - accuracy: 0.9167 - val_loss: 0.8840 - val_accuracy: 0.7500
# Epoch 71/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.3149 - accuracy: 0.9062 - val_loss: 0.9092 - val_accuracy: 0.7500
# Epoch 72/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.3495 - accuracy: 0.8958 - val_loss: 0.8965 - val_accuracy: 0.7083
# Epoch 73/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.2874 - accuracy: 0.9167 - val_loss: 0.8862 - val_accuracy: 0.7083
# Epoch 74/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.3116 - accuracy: 0.8854 - val_loss: 0.8950 - val_accuracy: 0.7500
# Epoch 75/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.3140 - accuracy: 0.9167 - val_loss: 0.9218 - val_accuracy: 0.7500
# Epoch 76/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2645 - accuracy: 0.9583 - val_loss: 0.9445 - val_accuracy: 0.7083
# Epoch 77/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.2791 - accuracy: 0.9375 - val_loss: 0.9588 - val_accuracy: 0.6667
# Epoch 78/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.2523 - accuracy: 0.9479 - val_loss: 0.9237 - val_accuracy: 0.7500
# Epoch 79/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2940 - accuracy: 0.9271 - val_loss: 0.9120 - val_accuracy: 0.7500
# Epoch 80/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.2646 - accuracy: 0.9583 - val_loss: 0.8928 - val_accuracy: 0.7500
# Epoch 81/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2082 - accuracy: 0.9583 - val_loss: 0.8668 - val_accuracy: 0.7917
# Epoch 82/100
# 2/2 [==============================] - 0s 108ms/step - loss: 0.2201 - accuracy: 0.9583 - val_loss: 0.8628 - val_accuracy: 0.7917
# Epoch 83/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2546 - accuracy: 0.9375 - val_loss: 0.8761 - val_accuracy: 0.7500
# Epoch 84/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.2099 - accuracy: 0.9479 - val_loss: 0.9217 - val_accuracy: 0.7500
# Epoch 85/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.2413 - accuracy: 0.9167 - val_loss: 0.9006 - val_accuracy: 0.7500
# Epoch 86/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.2793 - accuracy: 0.9167 - val_loss: 0.8738 - val_accuracy: 0.7500
# Epoch 87/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.2065 - accuracy: 0.9583 - val_loss: 0.9173 - val_accuracy: 0.7500
# Epoch 88/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.2544 - accuracy: 0.9167 - val_loss: 0.9658 - val_accuracy: 0.7500
# Epoch 89/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2742 - accuracy: 0.9062 - val_loss: 0.9081 - val_accuracy: 0.7500
# Epoch 90/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.2064 - accuracy: 0.9583 - val_loss: 0.8951 - val_accuracy: 0.7500
# Epoch 91/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.2226 - accuracy: 0.9688 - val_loss: 0.8581 - val_accuracy: 0.7917
# Epoch 92/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.2154 - accuracy: 0.9479 - val_loss: 0.8950 - val_accuracy: 0.7917
# Epoch 93/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2053 - accuracy: 0.9583 - val_loss: 0.9150 - val_accuracy: 0.7917
# Epoch 94/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2057 - accuracy: 0.9375 - val_loss: 0.8924 - val_accuracy: 0.7500
# Epoch 95/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1905 - accuracy: 0.9479 - val_loss: 0.9036 - val_accuracy: 0.7500
# Epoch 96/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2293 - accuracy: 0.9479 - val_loss: 0.9221 - val_accuracy: 0.7500
# Epoch 97/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.1739 - accuracy: 0.9479 - val_loss: 0.9516 - val_accuracy: 0.6667
# Epoch 98/100
# 2/2 [==============================] - 0s 97ms/step - loss: 0.2157 - accuracy: 0.9271 - val_loss: 0.9272 - val_accuracy: 0.7083
# Epoch 99/100
# 2/2 [==============================] - 0s 100ms/step - loss: 0.1544 - accuracy: 0.9479 - val_loss: 0.8838 - val_accuracy: 0.7500
# Epoch 100/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1633 - accuracy: 0.9583 - val_loss: 0.9133 - val_accuracy: 0.7083
# Test Accuracy: 71.510%
# 313/313 [==============================] - 3s 8ms/step
